# %% [markdown]
# ## Student Exams DataSet
# ### 1] Find the duplicates values and delete Duplicate values.
# ### 2] Find the NULL values.
# ### 3] Find How many Males and Females And plot their BAR grpah.
# ### 4] Find How many students completed their preparation And How many students NOT completed their preparation And make PIE chart.
# ### Find TOP 5  - i] Math score
# ###                       ii] Reading score
# ###                       ii] Writing score
# ###                       ii] Total score

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('exams.csv')

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0      male        group A                 high school      standard
# 1    female        group D            some high school  free/reduced
# 2      male        group E                some college  free/reduced
# 3      male        group B                 high school      standard
# 4      male        group E          associate's degree      standard
# ..      ...            ...                         ...           ...
# 995    male        group C                 high school      standard
# 996    male        group D          associate's degree  free/reduced
# 997  female        group C            some high school  free/reduced
# 998  female        group C                some college      standard
# 999    male        group A                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group A                 high school      standard
# 1  female        group D            some high school  free/reduced
# 2    male        group E                some college  free/reduced
# 3    male        group B                 high school      standard
# 4    male        group E          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 0               completed          67             67             63
# 1                    none          40             59             55
# 2                    none          59             60             50
# 3                    none          77             78             68
# 4               completed          78             73             68

# %%
df.isnull()     #it's shows the true or false
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0     False           False                        False  False
# 1     False           False                        False  False
# 2     False           False                        False  False
# 3     False           False                        False  False
# 4     False           False                        False  False
# ..      ...             ...                          ...    ...
# 995   False           False                        False  False
# 996   False           False                        False  False
# 997   False           False                        False  False
# 998   False           False                        False  False
# 999   False           False                        False  False
#
#      test preparation course  math score  reading score  writing score
# 0                      False       False          False          False
# ...

# %%
df.isnull().sum()    #it's show the sum of null values
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
# there are no null values

# %%
#-----------------------------------------------------------------------------------------------

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
df[df.duplicated()]
# Out:
#     gender race/ethnicity parental level of education     lunch  \
# 825   male        group E          associate's degree  standard
#
#     test preparation course  math score  reading score  writing score
# 825               completed         100            100            100

# %%
##inly one duplicated value

# %%
df.drop_duplicates()                      #it remove duplicated rows but this not permant
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0      male        group A                 high school      standard
# 1    female        group D            some high school  free/reduced
# 2      male        group E                some college  free/reduced
# 3      male        group B                 high school      standard
# 4      male        group E          associate's degree      standard
# ..      ...            ...                         ...           ...
# 995    male        group C                 high school      standard
# 996    male        group D          associate's degree  free/reduced
# 997  female        group C            some high school  free/reduced
# 998  female        group C                some college      standard
# 999    male        group A                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.drop_duplicates(inplace = True)   # this delete data permentally [inplace]

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [gender, race/ethnicity, parental level of education, lunch, test preparation course, math score, reading score, writing score]
# Index: []

# %%
#there are no duplicated values..... (:

# %%
#-------------------------------------------------------------------------------------------------

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group A                 high school      standard
# 1  female        group D            some high school  free/reduced
# 2    male        group E                some college  free/reduced
# 3    male        group B                 high school      standard
# 4    male        group E          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 0               completed          67             67             63
# 1                    none          40             59             55
# 2                    none          59             60             50
# 3                    none          77             78             68
# 4               completed          78             73             68

# %%
df.count()
# Out:
# gender                         999
# race/ethnicity                 999
# parental level of education    999
# lunch                          999
# test preparation course        999
# math score                     999
# reading score                  999
# writing score                  999
# dtype: int64

# %%
co_male = df[df['gender'] == 'male']['gender'].count()     #count male
co_male
# Out:
# 516

# %%
co_female = df[df['gender'] == 'female']['gender'].count()    #count female
co_female
# Out:
# 483

# %%
516+483     #total 999......  (:
# Out:
# 999

# %%
#-------------------------------------------------------------------------------------------

# %%
import matplotlib.pyplot as plt

# %%
key = ['male','female']
values = [co_male,co_female]

# %%
plt.bar(key,values , color= 'blue' , width = 0.2)
plt.show()                #bar graph of male and female

# %%
#----------------------------------------------------------------------------------------------------

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group A                 high school      standard
# 1  female        group D            some high school  free/reduced
# 2    male        group E                some college  free/reduced
# 3    male        group B                 high school      standard
# 4    male        group E          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 0               completed          67             67             63
# 1                    none          40             59             55
# 2                    none          59             60             50
# 3                    none          77             78             68
# 4               completed          78             73             68

# %%
## how many students are completed there test preparation

# %%
test_per_compl = df[df['test preparation course']== 'completed']['test preparation course'].count()
test_per_compl
# Out:
# 334

# %%
## how many students are NOT completed there test preparation

# %%
test_per_not_compl = df[df['test preparation course']== 'none']['test preparation course'].count()
test_per_not_compl
# Out:
# 665

# %%
334+665          #count
# Out:
# 999

# %%
t_p_c = test_per_compl*100/999      #percentage of test preparation completed
t_p_c
# Out:
# 33.433433433433436

# %%
t_p_n_c = test_per_not_compl*100/999    #percentage of test preparation NOT completed
t_p_n_c
# Out:
# 66.56656656656656

# %%
33.433433433433436+66.56656656656656
# Out:
# 100.0

# %%
plt.pie([t_p_c,t_p_n_c], labels=['test preparation completed','test preparation NOT completed'], shadow= True)
# Out:
# ([<matplotlib.patches.Wedge at 0x1a7bef5d690>,
# ...
#  [Text(0.5470014926511241, 0.9543528524803824, 'test preparation completed'),
#   Text(-0.5470014032981588, -0.9543529036943542, 'test preparation NOT completed')])

# %%
#----------------------------------------------------------------------------------------------------

# %%
#TOP 5 math score

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group A                 high school      standard
# 1  female        group D            some high school  free/reduced
# 2    male        group E                some college  free/reduced
# 3    male        group B                 high school      standard
# 4    male        group E          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 0               completed          67             67             63
# 1                    none          40             59             55
# 2                    none          59             60             50
# 3                    none          77             78             68
# 4               completed          78             73             68

# %%
larg_math = df.nlargest(5, 'math score')                   #TOP 5 math scores
larg_math
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 44     male        group E                 high school  standard
# 128    male        group E                some college  standard
# 148  female        group E           bachelor's degree  standard
# 235    male        group C          associate's degree  standard
# 281    male        group E          associate's degree  standard
#
#     test preparation course  math score  reading score  writing score
# 44                     none         100             88             87
# 128               completed         100             84             87
# 148               completed         100            100            100
# 235               completed         100             91             90
# 281               completed         100            100            100

# %%
larg_reading = df.nlargest(5, 'reading score')                 #TOP 5 Reading score
larg_reading
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 96   female        group E          associate's degree  standard
# 148  female        group E           bachelor's degree  standard
# 185  female        group C             master's degree  standard
# 273  female        group E                 high school  standard
# 281    male        group E          associate's degree  standard
#
#     test preparation course  math score  reading score  writing score
# 96                completed          95            100            100
# 148               completed         100            100            100
# 185                    none          91            100             99
# 273                    none          93            100             93
# 281               completed         100            100            100

# %%
larg_Writing = df.nlargest(5, 'writing score')                    #TOP 5 Writing Score
larg_Writing
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 96   female        group E          associate's degree      standard
# 129  female        group D          associate's degree  free/reduced
# 148  female        group E           bachelor's degree      standard
# 281    male        group E          associate's degree      standard
# 396  female        group D          associate's degree      standard
#
#     test preparation course  math score  reading score  writing score
# 96                completed          95            100            100
# 129               completed          83             95            100
# 148               completed         100            100            100
# 281               completed         100            100            100
# 396                    none          85            100            100

# %%
#-----------------------------------------------------------------------------------------------------------

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group A                 high school      standard
# 1  female        group D            some high school  free/reduced
# 2    male        group E                some college  free/reduced
# 3    male        group B                 high school      standard
# 4    male        group E          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score  total
# 0               completed          67             67             63    197
# 1                    none          40             59             55    154
# 2                    none          59             60             50    169
# 3                    none          77             78             68    223
# 4               completed          78             73             68    219

# %%
df['total'] = df['math score'] + df['reading score'] + df['writing score']

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group A                 high school      standard
# 1  female        group D            some high school  free/reduced
# 2    male        group E                some college  free/reduced
# 3    male        group B                 high school      standard
# 4    male        group E          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score  total
# 0               completed          67             67             63    197
# 1                    none          40             59             55    154
# 2                    none          59             60             50    169
# 3                    none          77             78             68    223
# 4               completed          78             73             68    219

# %%
#--------------TOP 5 TOTAL MARKS------------------------------------

# %%
Hig_marks = df.nlargest(5, 'total')
Hig_marks
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 148  female        group E           bachelor's degree  standard
# 281    male        group E          associate's degree  standard
# 550  female        group E                some college  standard
# 634  female        group D             master's degree  standard
# 593    male        group D           bachelor's degree  standard
#
#     test preparation course  math score  reading score  writing score  total
# 148               completed         100            100            100    300
# 281               completed         100            100            100    300
# 550               completed         100            100            100    300
# 634               completed         100            100            100    300
# 593               completed         100             97            100    297

# %%
#-----------------------------------------------------------------------------------------------------
